# %% [markdown]
# <a href="https://colab.research.google.com/github/chiragvijay13/26thmay_B1_AI/blob/day-15/USA_Housing_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Make aa Machine learning model to predict the price of a House**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import statsmodels.api as sm

# %%
  df = pd.read_csv('/content/housing.csv')

# %%
df.head()
# Out:
#    Avg. Area Income  ...                                            Address
# 0      79545.458574  ...  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1      79248.642455  ...  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2      61287.067179  ...  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3      63345.240046  ...                          USS Barnett\nFPO AP 44820
# 4      59982.197226  ...                         USNS Raymond\nFPO AE 09386
#
# [5 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  ...  Area Population         Price
# count       5000.000000          5000.000000  ...      5000.000000  5.000000e+03
# mean       68583.108984             5.977222  ...     36163.516039  1.232073e+06
# std        10657.991214             0.991456  ...      9925.650114  3.531176e+05
# min        17796.631190             2.644304  ...       172.610686  1.593866e+04
# 25%        61480.562388             5.322283  ...     29403.928702  9.975771e+05
# 50%        68804.286404             5.970429  ...     36199.406689  1.232669e+06
# 75%        75783.338666             6.650808  ...     42861.290769  1.471210e+06
# max       107701.748378             9.519088  ...     69621.713378  2.469066e+06
#
# [8 rows x 6 columns]

# %%
df.corr()
# Out:
#                               Avg. Area Income  ...     Price
# Avg. Area Income                      1.000000  ...  0.639734
# Avg. Area House Age                  -0.002007  ...  0.452543
# Avg. Area Number of Rooms            -0.011032  ...  0.335664
# Avg. Area Number of Bedrooms          0.019788  ...  0.171071
# Area Population                      -0.016234  ...  0.408556
# Price                                 0.639734  ...  1.000000
#
# [6 rows x 6 columns]

# %%
for i in df.columns[:-1]:
  df[i].hist(bins=20)
  plt.title(i)
  plt.show()

# %%
for i in df.columns[:-2]:
  plt.scatter(df['Price'],df[i])
  plt.title(i + 'vs price')
  plt.xlabel('price')
  plt.ylabel(i)
  plt.grid()
  plt.show()

# %%
sns.pairplot(df, kind='reg')

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
x = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms', 'Area Population']]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Avg. Area Income           5000 non-null   float64
#  1   Avg. Area House Age        5000 non-null   float64
#  2   Avg. Area Number of Rooms  5000 non-null   float64
#  3   Area Population            5000 non-null   float64
# dtypes: float64(4)
# memory usage: 156.4 KB

# %%
y = df[['Price']]

# %%
y
# Out:
#              Price
# 0     1.059034e+06
# 1     1.505891e+06
# 2     1.058988e+06
# 3     1.260617e+06
# 4     6.309435e+05
# ...            ...
# 4995  1.060194e+06
# 4996  1.482618e+06
# 4997  1.030730e+06
# 4998  1.198657e+06
# 4999  1.298950e+06
#
# [5000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y, test_size=0.25 ,random_state = 10)

# %%
xtest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1250 entries, 245 to 1234
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Avg. Area Income           1250 non-null   float64
#  1   Avg. Area House Age        1250 non-null   float64
#  2   Avg. Area Number of Rooms  1250 non-null   float64
#  3   Area Population            1250 non-null   float64
# dtypes: float64(4)
# memory usage: 48.8 KB

# %%
ytrain.shape
# Out:
# (3750, 1)

# %%
ytest.shape
# Out:
# (1250, 1)

# %%
xtrain.head()
# Out:
#       Avg. Area Income  ...  Area Population
# 4875      58676.411529  ...     56269.462943
# 2773      59046.444231  ...     37813.714630
# 4391      50703.152916  ...     26324.207865
# 3433      79263.554759  ...     36164.655454
# 3764      55593.079806  ...     42067.693935
#
# [5 rows x 4 columns]

# %% [markdown]
# **creating the ML model**

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %% [markdown]
# **bold texTraining the model with training model**

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# **Evaluation**

# %%
print('%.1f%%'%(model.score(xtest,ytest)*100))
# Out:
# 91.8%

# %%
ypred = model.predict(xtest)

# %%
ypred
# Out:
# array([[1193899.36335106],
#        [1187262.43784593],
#        [1046347.43872965],
#        ...,
#        [ 769979.21424073],
#        [1588323.12890357],
#        [1732539.85447351]])

# %%
ytest
# Out:
#              Price
# 245   1.118048e+06
# 4493  1.326947e+06
# 4583  1.053485e+06
# 2242  7.590447e+05
# 3407  1.381118e+06
# ...            ...
# 4274  1.779858e+06
# 2551  1.404541e+06
# 2476  9.143783e+05
# 3711  1.479296e+06
# 1234  1.747245e+06
#
# [1250 rows x 1 columns]

# %%
from sklearn.metrics import mean_absolute_error

# %%
print(mean_absolute_error(ytest,ypred))
# Out:
# 80728.01465731302

# %%
ypred[0]
# Out:
# array([1193899.36335106])

# %%
100*mean_absolute_error(ytest,ypred)/ypred[0]
# Out:
# array([6.76171017])

# %%
#accuracy = 1-error
# error = 1-accuracy

# %% [markdown]
# ***conclusion : lets use this model bcoz its accuracy is moore than 90%***

# %% [markdown]
# # Deployment

# %%
final_model = model

# %%
pd.to_pickle(final_model, 'HousePricePredictor')
